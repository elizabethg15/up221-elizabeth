# %% [markdown]
# # Assignment for Week 2 of UP221 (W23)
# ##### Student: Elizabeth Greenfield
# ##### Date: January 22, 2023
# ##### Summary of assignment: Find and download assignment of your choice

# %% [markdown]
# ### List of required functions for this assignment
# ##### [x] .shape
# ##### [x] .info
# ##### [x] .head()
# ##### [x] .plot()
# ##### [x] .value_counts()
# ##### [x] run a query to filter the data

# %%
# import pandas and geopandas
import pandas as pd
import geopandas as gpd

# %%
# I'm having trouble getting the file read. 
#I found this tutorial to double check that the file being referred to is indeed there.

import os
  
# If we do not specify any path
# os.listdir() method will return
# the list of all files and directories
# in current working directory
  
dir_list = os.listdir()
  
print("Files and directories in  current working directory :") 
  
# print the list
print(dir_list)
# Out:
# Files and directories in  current working directory :
# ['Greenfield_Week2Assignment.ipynb', 'Greenfield_Week2Assignment_v2.ipynb', 'W201-PythonReview.ipynb', 'W202-PythonandMetro.ipynb', '.ipynb_checkpoints', 'mbs_trips_2019_q3.csv', 'metro.html']

# %%
# import dataset (variable name = df). 
# Data is the ridership of Metro Bike Share bikes during quarter 3 of 2019. 
# I chose this dataset to describe what is the pre-pandemic peak (summer months of 2019).
## I spent 30+ minutes on this line... 
## solution was adding "week2/" to the file name.... 
## and then that stopped working when I accidentally reset the kernel. 
## Honestly not sure why that worked but note to self.
df = gpd.read_file('mbs_trips_2019_q3.csv')

# %%
# confirming that data is now a GeoDataFrame
type(df)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Shape of dataset. This dataset is 92,124 rows and 16 columns.
df.shape
# Out:
# (92124, 16)

# %%
# List of columns. 
# Includes length of bike trip in minutes, start and end times/stations/lat/long, bike id, membership type, bike type, and geometry.
df.columns.to_list()
# Out:
# ['trip_id',
#  'duration',
#  'start_time',
#  'end_time',
#  'start_station',
#  'start_lat',
#  'start_lon',
#  'end_station',
#  'end_lat',
#  'end_lon',
#  'bike_id',
#  'plan_duration',
#  'trip_route_category',
#  'passholder_type',
#  'bike_type',
#  'geometry']

# %%
# information about dataset. 
# Shows content of first 5 rows and the associated columns.
df.info
# Out:
# <bound method DataFrame.info of          trip_id duration       start_time         end_time start_station  \
# 0      124657107        5    7/1/2019 0:04    7/1/2019 0:09          4312
# 1      124657587        9    7/1/2019 0:07    7/1/2019 0:16          3066
# 2      124658068        5    7/1/2019 0:20    7/1/2019 0:25          4410
# 3      124659747       20    7/1/2019 0:44    7/1/2019 1:04          3045
# 4      124660227       27    7/1/2019 0:44    7/1/2019 1:11          3035
# ...          ...      ...              ...              ...           ...
# 92119  130053092        8  9/30/2019 23:32  9/30/2019 23:40          3038
# 92120  130053090       15  9/30/2019 23:38  9/30/2019 23:53          4401
# 92121  130053089        1  9/30/2019 23:40  9/30/2019 23:41          3038
# 92122  130053088       22  9/30/2019 23:41   10/1/2019 0:03          3067
# 92123  130053087        4  9/30/2019 23:58   10/1/2019 0:02          4417
#
# ...

# %%
# first 10 rows of data (head)
df.head(10)
# Out:
#      trip_id duration     start_time       end_time start_station  start_lat  \
# 0  124657107        5  7/1/2019 0:04  7/1/2019 0:09          4312   34.06699
# 1  124657587        9  7/1/2019 0:07  7/1/2019 0:16          3066  34.063389
# 2  124658068        5  7/1/2019 0:20  7/1/2019 0:25          4410  34.063351
# 3  124659747       20  7/1/2019 0:44  7/1/2019 1:04          3045  34.028511
# 4  124660227       27  7/1/2019 0:44  7/1/2019 1:11          3035  34.048401
# 5  124659507        7  7/1/2019 0:51  7/1/2019 0:58          3056   34.03746
# 6  124662392       37  7/1/2019 1:22  7/1/2019 1:59          3047  34.039982
# 7  124663117        8  7/1/2019 2:06  7/1/2019 2:14          3069   34.05088
# 8  124664810        4  7/1/2019 2:43  7/1/2019 2:47          3014   34.05661
# 9  124669422        4  7/1/2019 4:17  7/1/2019 4:21          3075   34.04211
#
#      start_lon end_station    end_lat      end_lon bike_id plan_duration  \
# ...

# %%
# last 10 rows of data (tail)
df.tail(10)
# Out:
#          trip_id duration       start_time         end_time start_station  \
# 92114  130053097      147  9/30/2019 23:03   10/1/2019 1:30          4345
# 92115  130053096        5  9/30/2019 23:04  9/30/2019 23:09          4390
# 92116  130053095        5  9/30/2019 23:08  9/30/2019 23:13          4345
# 92117  130053094       23  9/30/2019 23:15  9/30/2019 23:38          4401
# 92118  130053093       14  9/30/2019 23:20  9/30/2019 23:34          4415
# 92119  130053092        8  9/30/2019 23:32  9/30/2019 23:40          3038
# 92120  130053090       15  9/30/2019 23:38  9/30/2019 23:53          4401
# 92121  130053089        1  9/30/2019 23:40  9/30/2019 23:41          3038
# 92122  130053088       22  9/30/2019 23:41   10/1/2019 0:03          3067
# 92123  130053087        4  9/30/2019 23:58   10/1/2019 0:02          4417
#
#        start_lat    start_lon end_station    end_lat      end_lon bike_id  \
# 92114   33.99556  -118.481552        4345   33.99556  -118.481552   15883
# ...

# %%
# sample of ten rows of data
df.sample(10)
# Out:
#          trip_id duration       start_time         end_time start_station  \
# 23614  126165739        5  7/26/2019 17:21  7/26/2019 17:26          3030
# 91353  130012234        6   9/30/2019 9:35   9/30/2019 9:41          3014
# 25935  126331824       18  7/29/2019 14:37  7/29/2019 14:55          3035
# 17901  125813333       32  7/20/2019 17:16  7/20/2019 17:48          3037
# 75555  129096222       12  9/14/2019 18:41  9/14/2019 18:53          3031
# 7210   125143208        1    7/9/2019 6:51    7/9/2019 6:52          4254
# 1989   124791158        6    7/3/2019 5:47    7/3/2019 5:53          3018
# 5830   125049648       29   7/7/2019 14:28   7/7/2019 14:57          4346
# 40627  127190753        3   8/13/2019 9:09   8/13/2019 9:12          3082
# 51058  127726966        8  8/22/2019 14:03  8/22/2019 14:11          3029
#
#        start_lat    start_lon end_station    end_lat      end_lon bike_id  \
# 23614  34.051941   -118.24353        3014   34.05661  -118.237213    6717
# ...

# %%
# Value counts of how long the bike rides were. 
# There are clearly some outlier values at the top end, whereas most rides are under 30 minutes, which is how the system is designed. 
df['duration'].value_counts()
# Out:
# 5       5592
# 6       5313
# 4       5310
# 7       4908
# 3       4236
#         ...
# 1063       1
# 1103       1
# 431        1
# 916        1
# 690        1
# Name: duration, Length: 857, dtype: int64

# %%
# creating a new data frame focused on ride duration
ride_time = df['duration'].value_counts()

# %%
# converting duration column from string to integer. cell 1/3
type('duration')
# Out:
# str

# %%
#converting duration column from string to integer. cell 2/3
df['duration'] = df['duration'].astype(int)

# %%
#converting duration column from string to integer. cell 3/3
print (df.dtypes)
# Out:
# trip_id                  object
# duration                  int64
# start_time               object
# end_time                 object
# start_station            object
# start_lat                object
# start_lon                object
# end_station              object
# end_lat                  object
# end_lon                  object
# bike_id                  object
# plan_duration            object
# trip_route_category      object
# passholder_type          object
# bike_type                object
# geometry               geometry
# dtype: object

# %%
# Trying to find where the outlier values start and the genuine values end. 
# But all values won't show in a sample size much higher than 60, from what I can tell.
ride_time.tail(60)
# Out:
# 1195    1
# 1130    1
# 823     1
# 1212    1
# 623     1
# 468     1
# 1265    1
# 1414    1
# 1161    1
# 496     1
# 622     1
# 556     1
# 560     1
# 698     1
# 1134    1
# 1242    1
# 1272    1
# 1369    1
# 1381    1
# 1284    1
# 1424    1
# 595     1
# 1093    1
# 870     1
# 1034    1
# 953     1
# 864     1
# 1301    1
# 1056    1
# 1088    1
# 407     1
# 825     1
# 714     1
# 1202    1
# 1110    1
# 1011    1
# 1415    1
# 1286    1
# 1000    1
# 1087    1
# 686     1
# 1173    1
# 917     1
# 1083    1
# 973     1
# 1394    1
# 913     1
# 728     1
# 615     1
# 729     1
# 1178    1
# 1222    1
# 312     1
# 1240    1
# 380     1
# 1063    1
# 1103    1
# 431     1
# 916     1
# 690     1
# Name: duration, dtype: int64

# %%
# Getting to know the dataset.
# How many entries are there where duration = 300? (Answer : 2)
df.query("duration == 300")
# Out:
#          trip_id  duration       start_time         end_time start_station  \
# 28814  126522402       300   8/1/2019 11:08   8/1/2019 16:08          3049
# 75043  129103070       300  9/14/2019 11:00  9/14/2019 16:00          4302
#
#        start_lat    start_lon end_station    end_lat      end_lon bike_id  \
# 28814  34.056969  -118.253593        3000                            6634
# 75043  34.092491  -118.291443        4302  34.092491  -118.291443   12149
#
#       plan_duration trip_route_category passholder_type bike_type geometry
# 28814             1             One Way         Walk-up  standard     None
# 75043             1          Round Trip         Walk-up  standard     None

# %%
# Getting to know the dataset. 
# I know there are some outlier or coded very large durations in the dataset. 
# I'm trying to figure out where the genuine entries end in place of the coded (e.g, '9999') entries. 
# Couldn't find it in an objective way, but I decided 3 hours (180 minutes) is a fine place to trim it at. 
df[df.duration <= 180]
# Out:
#          trip_id  duration       start_time         end_time start_station  \
# 0      124657107         5    7/1/2019 0:04    7/1/2019 0:09          4312
# 1      124657587         9    7/1/2019 0:07    7/1/2019 0:16          3066
# 2      124658068         5    7/1/2019 0:20    7/1/2019 0:25          4410
# 3      124659747        20    7/1/2019 0:44    7/1/2019 1:04          3045
# 4      124660227        27    7/1/2019 0:44    7/1/2019 1:11          3035
# ...          ...       ...              ...              ...           ...
# 92119  130053092         8  9/30/2019 23:32  9/30/2019 23:40          3038
# 92120  130053090        15  9/30/2019 23:38  9/30/2019 23:53          4401
# 92121  130053089         1  9/30/2019 23:40  9/30/2019 23:41          3038
# 92122  130053088        22  9/30/2019 23:41   10/1/2019 0:03          3067
# 92123  130053087         4  9/30/2019 23:58   10/1/2019 0:02          4417
#
# ...

# %%
# Creating a new data frame of rides with duration equal or less than 3 hours (180 minutes).
ride_time_trimmed = df[df.duration <= 180]

# %%
# Double checking that the ride_time_trimmed dataframe has indeed trimmed all cells where the "duration" is greater than 180.
ride_time_trimmed.query("duration == 181")
# Out:
# Empty GeoDataFrame
# Columns: [trip_id, duration, start_time, end_time, start_station, start_lat, start_lon, end_station, end_lat, end_lon, bike_id, plan_duration, trip_route_category, passholder_type, bike_type, geometry]
# Index: []

# %%
# Plot #1
# Plot bar graph of duration of rides. 
# I wanted to trim out the large values and use the ride_time_trimmed dataframe but I couldn't quite figure out a way to do that.
ride_time.plot.bar(x='duration',y='count',title='Duration of MBS rides',figsize = (15,6))
# Out:
# <AxesSubplot: title={'center': 'Duration of MBS rides'}>

# %%
# Plot #2
# Plotting a histogram on the duration of each ride. 
# Each column represents 10-minute intervals, from 0 minutes to 180 minutes.
ax = ride_time_trimmed.plot.hist(column=["duration"],bins=18,title='Metro Bike Share Ride Length Frequency',figsize=(10, 8))

# %%
import folium
m = folium.Map()

# %%
latitude = ride_time_trimmed.start_lat
latitude
# Out:
# 0         34.06699
# 1        34.063389
# 2        34.063351
# 3        34.028511
# 4        34.048401
#            ...
# 92119    34.046822
# 92120    34.075611
# 92121    34.046822
# 92122    34.045181
# 92123    34.164951
# Name: start_lat, Length: 90247, dtype: object

# %%
longitude = ride_time_trimmed.start_lon
longitude
# Out:
# 0        -118.290878
# 1         -118.23616
# 2        -118.296799
# 3        -118.256668
# 4        -118.260948
#             ...
# 92119    -118.248352
# 92120    -118.291862
# 92121    -118.248352
# 92122    -118.250237
# 92123    -118.363632
# Name: start_lon, Length: 90247, dtype: object

# %%
# Creating a map. 
# Inputted one of the entries lat/long because couldn't calculate averages with float values.
m = folium.Map(location=[34.164951,-118.363632])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Trying to prepare data markers to add to map
# first, note how to loop through a dataframe:
for index, row in ride_time_trimmed.iterrows():
    print(row.start_lat, row.start_lon, row.duration)
# Out:
# 34.06699 -118.290878 5
# 34.063389 -118.23616 9
# 34.063351 -118.296799 5
# 34.028511 -118.256668 20
# 34.048401 -118.260948 27
# 34.03746 -118.265381 7
# 34.039982 -118.266403 37
# 34.05088 -118.248253 8
# 34.05661 -118.237213 4
# 34.04211 -118.256187 4
# 34.014309 -118.491341 4
# 34.014309 -118.491341 72
# 33.997231 -118.445969 17
# 34.05048 -118.254593 18
# 34.0485 -118.258537 98
# 34.049301 -118.238808 5
# 34.057652 -118.292183 6
# 34.022518 -118.400589 24
# 34.052898 -118.241562 6
# 34.049301 -118.238808 6
# 34.063389 -118.23616 11
# 34.04607 -118.233093 6
# 34.05661 -118.237213 16
# 34.05661 -118.237213 6
# 34.05661 -118.237213 7
# 34.049301 -118.238808 4
# 34.05357 -118.266357 16
# 34.069271 -118.296593 3
# 34.042061 -118.263382 9
# 34.05661 -118.237213 7
# 34.06699 -118.290878 10
# 34.05661 -118.237213 21
# 34.0406 -118.253838 9
# 34.0298 -118.270309 2
# 34.03286 -118.268082 5
# 34.063389 -118.23616 13
# 34.074829 -118.258728 44
# 34.063179 -118.24588 6
# ...

# %%
# Continuing with code modifications from the example in lab.
# Didn't get all the way there. 
# I think the issue is that the long/lat values are strings, not floats or geometric. 
# Also I'm trying to plot from a CSV vs. a shapefile which might be a problem.
# Anyway, we got a good start...
for index, row in ride_time_trimmed.iterrows():
    # add folium marker code
    folium.Marker([row.start_lat, row.start_lon], popup=row.duration, tooltip=row.duration).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/folium/utilities.py:69, in validate_location(location)
#      68 try:
# ---> 69     float(coord)
#      70 except (TypeError, ValueError):
#
# ValueError: could not convert string to float: ''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[184], line 8
#       1 # Continuing with code modifications from the example in lab.
#       2 # Didn't get all the way there.
#       3 # I think the issue is that the long/lat values are strings, not floats or geometric.
#       4 # Also I'm trying to plot from a CSV vs. a shapefile which might be a problem.
#       5 # Anyway, we got a good start...
#       6 for index, row in ride_time_trimmed.iterrows():
# ...
