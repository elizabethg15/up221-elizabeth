# %% [markdown]
# # Metro Bus Stops

# %%
import pandas as pd
import geopandas as gpd
# !pip install pyshp
import shapefile as shp  # Requires the pyshp package
import matplotlib.pyplot as plt
import contextily as ctx

# for interactive plots
import plotly.express as px

# to import open data
from sodapy import Socrata

# %%
#plot SHX of Metro Bus Stops Serving Lines
shape=gpd.read_file('data/StopServingLines1022.shx')
shape.plot()
# Out:
# <AxesSubplot: >

# %%
df = gpd.read_file('data/StopServingLines1022.shx')

# %%
df.head()
# Out:
#    STOPNUM                             STOPNAME        LAT        LONG  \
# 0        1                  Paramount / Slauson  33.973248 -118.113113
# 1        3                     Jefferson / 10th  34.025471 -118.328402
# 2        6           120th / Augustus F Hawkins  33.924696 -118.242222
# 3        7  120th / Martin Luther King Hospital  33.924505 -118.240369
# 4       12                    15054 Sherman Way  34.201075 -118.461953
#
#   LINE_DIR1 LINE_DIR2 LINE_DIR3 LINE_DIR4 LINE_DIR5 LINE_DIR6 LINE_DIR7  \
# 0     108-E     265-S      None      None      None      None      None
# 1      35-N      None      None      None      None      None      None
# 2      53-N     120-W      55-N      None      None      None      None
# 3      55-S     120-E      None      None      None      None      None
# 4     162-E      None      None      None      None      None      None
#
#   LINE_DIR8 LINE_DIR9 LINE_DIR10 LINE_DIR11 LINE_DIR12 LINE_DIR13 LINE_DIR14  \
# ...

# %%
#plot SHX of Metro LINES Serving Bus STOPS
shape=gpd.read_file('data/LineServingStops1022.shx')
shape.plot()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Unable to open data/LineServingStops1022.shp or data/LineServingStops1022.SHP.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[19], line 2
#       1 #plot SHX of Metro LINES Serving Bus STOPS
# ----> 2 shape=gpd.read_file('data/LineServingStops1022.shx')
#       3 shape.plot()
#
# File /opt/conda/lib/python3.10/site-packages/geopandas/io/file.py:259, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     256     path_or_bytes = filename
#     258 if engine == "fiona":
# --> 259     return _read_file_fiona(
# ...
